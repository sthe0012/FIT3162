# %% [markdown]
# ## This module extracts Gaze and Micro-Expression features using OpenFace
#
# Static gaze features and facial action features are extracted using OpenFace
#
# Import necessary Packages

# %%
import os
import sys
import glob
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import walk
from os.path import splitext
from os.path import join

# %% [markdown]
# ### Count the number of videos from Trial dataset and add them to a list

# %%
videolist = list()
#Execute from commandline
#dir_list contains path of all files which contains the audio 

"""
# onji
dir_list=["/Users/jingweiong/Downloads/Real-life_Deception_Detection_2016/Clips/Deceptive"
          ,"/Users/jingweiong/Downloads/Real-life_Deception_Detection_2016/Clips/Truthful"]
"""

# jk
dir_list = [
    r"D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive",
    r"D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful"
]

count_trial=0
for dir in dir_list:
    for filename in glob.glob(os.path.join(dir, '*.mp4')):
        videolist.append(filename)
        count_trial +=1
        
print("number of videos from trial data")
print(count_trial)
# Out:
# number of videos from trial data
# 121

# %% [markdown]
# ### Count the number of videos from Trial dataset and add them to a list

# %%
"""
# onji
cmd1 ="/Users/jingweiong/openFace/OpenFace/build/bin/"
"""
# jk
cmd1 ="D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64"

os.system(cmd1)
dict_input_output={}
output_filename_list=list()

gaze_trial=0
for filename in videolist:
    output_filename=""
    ip=filename
    
    if "Real-life_Deception_Detection_2016" in filename:
        cmd2=""
        x=os.path.split(filename)[0]
        x1=os.path.split(filename)[-1]
        y=os.path.split(x)[0]
        y1=os.path.split(x)[-1]
        output_filename="Gaze_reallifedeception_"+x1
        output_filename=output_filename.replace(".mp4",".csv")
        op = "D:\\fit3162\\dataset\\output\\"+output_filename
        cmd2="\FeatureExtraction.exe -f "+ "\"" + ip + "\"" + " -of " + "\"" + op +"\""+ " -gaze"
        o1=os.system(cmd1 + cmd2)
        if(o1==0):
            gaze_trial +=1
            dict_input_output[filename]=op
            output_filename_list.append(op)

print("converted wav files counts are:")
print("Trail = "+str(gaze_trial))
# Out:
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_001.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_001.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_002.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_002.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_003.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_003.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_004.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_004.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_005.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_005.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_006.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_006.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_007.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_007.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_008.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_008.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_009.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_009.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_010.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_010.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_011.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_011.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_012.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_012.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_013.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_013.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_014.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_014.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_015.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_015.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_016.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_016.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_017.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_017.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_018.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_018.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_019.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_019.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_020.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_020.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_021.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_021.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_022.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_022.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_023.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_023.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_024.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_024.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_025.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_025.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_026.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_026.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_027.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_027.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_028.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_028.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_029.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_029.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_030.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_030.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_031.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_031.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_032.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_032.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_033.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_033.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_034.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_034.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_035.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_035.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_036.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_036.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_037.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_037.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_038.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_038.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_039.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_039.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_040.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_040.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_041.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_041.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_042.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_042.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_043.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_043.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_044.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_044.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_045.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_045.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_046.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_046.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_047.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_047.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_048.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_048.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_049.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_049.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_050.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_050.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_051.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_051.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_052.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_052.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_053.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_053.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_054.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_054.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_055.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_055.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_056.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_056.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_057.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_057.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_058.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_058.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_059.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_059.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_060.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_060.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_061.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_lie_061.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_001.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_001.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_002.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_002.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_003.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_003.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_004.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_004.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_005.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_005.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_006.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_006.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_007.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_007.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_008.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_008.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_009.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_009.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_010.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_010.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_011.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_011.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_012.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_012.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_013.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_013.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_014.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_014.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_015.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_015.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_016.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_016.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_017.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_017.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_018.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_018.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_019.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_019.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_020.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_020.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_021.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_021.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_022.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_022.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_023.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_023.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_024.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_024.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_025.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_025.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_026.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_026.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_027.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_027.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_028.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_028.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_029.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_029.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_030.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_030.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_031.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_031.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_032.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_032.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_033.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_033.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_034.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_034.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_035.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_035.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_036.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_036.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_037.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_037.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_038.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_038.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_039.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_039.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_040.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_040.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_041.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_041.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_042.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_042.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_043.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_043.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_044.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_044.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_045.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_045.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_046.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_046.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_047.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_047.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_048.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_048.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_049.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_049.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_050.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_050.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_051.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_051.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_052.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_052.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_053.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_053.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_054.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_054.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_055.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_055.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_056.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_056.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_057.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_057.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_058.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_058.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_059.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_059.csv" -gaze
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Truthful\trial_truth_060.mp4" -of "D:\fit3162\dataset\output\Gaze_reallifedeception_trial_truth_060.csv" -gaze
# converted wav files counts are:
# Trail = 121

# %% [markdown]
# ### Generate a .csv file with annotations and file names for gaze data

# %%
head = ["Path_for_mp4_video", "csv_file_name", "csv_file_name_path_gaze_data", "label"]
data_frames = []
print(dict_input_output)
for key, value in dict_input_output.items():
    
    csv_file_name = os.path.basename(value)
    label = "Deceptive" if "reallifedeception" in value and "lie" in value else "Truthful"
    
    # Create a DataFrame for each row
    data = {
        'Path_for_mp4_video': [key],
        'csv_file_name': [csv_file_name],
        'csv_file_name_path_gaze_data': [value],
        'label': [label]
    }
    df_row = pd.DataFrame(data)
    data_frames.append(df_row)


# Concatenate all DataFrames into a single DataFrame
df_input_output = pd.concat(data_frames, ignore_index=True)

print(len(df_input_output.index))

"""
# onji
df_input_output.to_csv("/Users/jingweiong/Downloads/Deception_detection_output/Annotation_gaze_features.csv",index=False) 
"""

# jk
df_input_output.to_csv("D:\\fit3162\dataset\output\Annotation_gaze_features.csv",index=False)
# Out:
# {'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_001.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_001.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_002.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_002.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_003.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_003.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive
_Detection_2016\\Clips\\Deceptive\\trial_lie_018.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_018.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_019.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_019.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_020.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_020.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_021.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_021.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_022.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_022.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\Deceptive\\trial_lie_023.mp4': 'D:\\fit3162\\dataset\\output\\Gaze_reallifedeception_trial_lie_023.csv', 'D:\\fit3162\\dataset\\Real-life_Deception_Detection_2016\\Clips\\ ...
# 121

# %% [markdown]
# ### Finally Annotate the gaze data extracted using OpenFace with the csv file generated in the previous step

# %%
"""
# onji
df_readannotation=pd.read_csv("/Users/jingweiong/Downloads/Deception_detection_output/Annotation_gaze_features.csv")
dir="/Users/jingweiong/Downloads/Deception_detection_output"
"""

# jk
df_readannotation = pd.read_csv("D:\\fit3162\dataset\output\Annotation_gaze_features.csv")
dir = "D:\\fit3162\dataset\output"

for filename in glob.glob(os.path.join(dir, '*.csv')):
    file=os.path.basename(filename)
    df_readindividual=pd.read_csv(filename)
    for index, row in df_readannotation.iterrows():
            if(row["csv_file_name"]==file):
                val=row["label"]
                print(val)
                outputpath=row["csv_file_name_path_gaze_data"]
    df_readindividual["label"]=val
    df_readindividual.to_csv(outputpath)
# Out:
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Deceptive
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful
# Truthful

# %% [markdown]
# ### Extract Head_pose and facial action(Micro-expression) Features from Openface and store in a folder

# %%
"""
# onji
cmd1 ="/Users/jingweiong/openFace/OpenFace/build/bin/"
"""
# jk
cmd1 ="D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64"

os.system(cmd1)
dict_input_output={}
output_filename_list=list()

Mexp_trial=0
for filename in videolist:
    output_filename=""
    ip=filename
    if "Real-life_Deception_Detection_2016" in filename:
        cmd2=""
        x=os.path.split(filename)[0]
        x1=os.path.split(filename)[-1]
        y=os.path.split(x)[0]
        y1=os.path.split(x)[-1]
        output_filename="Mexp_reallifedeception_"+x1
        output_filename=output_filename.replace(".mp4",".csv")
        
        # onji
        #op = "/Users/jingweiong/Downloads/Deception_detection_output_mexp/"+output_filename
        #cmd2="FeatureExtraction -f " + ip + " -of " + op + " -pose -aus"
        
        # jk
        op = "D:\\fit3162\\dataset\\output_micro_expression\\"+output_filename                  
        cmd2="\FeatureExtraction.exe -f "+ "\"" + ip + "\"" + " -of " + "\"" + op +"\""+ " -gaze"
        
        o1=os.system(cmd1 + cmd2)
        if(o1==0):
            Mexp_trial +=1
            dict_input_output[filename]=op
            output_filename_list.append(op)
            
print("converted wav files counts are:")
print("Trail = "+str(Mexp_trial))
# Out:
# D:\OpenFace_2.2.0_win_x64\OpenFace_2.2.0_win_x64\FeatureExtraction.exe -f "D:\fit3162\dataset\Real-life_Deception_Detection_2016\Clips\Deceptive\trial_lie_001.mp4" -of "D:\fit3162\dataset\output_micro_expression\Mexp_reallifedeception_trial_lie_001.csv" -gaze
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 28
#      26 cmd2="\FeatureExtraction.exe -f "+ "\"" + ip + "\"" + " -of " + "\"" + op +"\""+ " -gaze"
#      27 print(cmd1 + cmd2)
# ---> 28 o1=os.system(cmd1 + cmd2)
#      29 if(o1==0):
#      30     Mexp_trial +=1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Generate a csv file with annotations and file names for Micro-Expression data

# %%
head = ["Path_for_mp4_video", "csv_file_name", "csv_file_name_path_mexp_data", "label"]
data_frames = []

for key, value in dict_input_output.items():
    csv_file_name = os.path.basename(value)
    label = "Deceptive" if "reallifedeception" in value and "lie" in value else "Truthful"
    
    # Create a DataFrame for each row
    data = {
        'Path_for_mp4_video': [key],
        'csv_file_name': [csv_file_name],
        'csv_file_name_path_mexp_data': [value],
        'label': [label]
    }
    df_row = pd.DataFrame(data)
    data_frames.append(df_row)

# Concatenate all DataFrames into a single DataFrame
df_input_output = pd.concat(data_frames, ignore_index=True)

print(len(df_input_output.index))

# onji
#df_input_output.to_csv("/Users/jingweiong/Downloads/Deception_detection_output/Annotation_mexp_features.csv",index=False) 

# jk
df_input_output.to_csv("D:\\fit3162\dataset\output_micro_expression\Annotation_mexp_features.csv",index=False)
# Out:
# 121

# %% [markdown]
# ### Finally Annotate the Micro-Expression data extracted using Openface with the csv file generated in the previous step

# %%
"""
# onji

df_readannotation=pd.read_csv("D:/hci lab/Mexp_Features/Annotation_mexp_features.csv")
dir="D:/hci lab/Mexp_Features"
"""
# jk
df_readannotation = pd.read_csv("D:\\fit3162\dataset\output_micro_expression\Annotation_mexp_features.csv")
dir = "D:\\fit3162\dataset\output_micro_expression"

for filename in glob.glob(os.path.join(dir, '*.csv')):
    file=os.path.basename(filename)
    df_readindividual=pd.read_csv(filename)
    for index, row in df_readannotation.iterrows():
            if(row["csv_file_name"]==file):
                val=row["label"]
                outputpath=row["csv_file_name_path_mexp_data"]
    df_readindividual["label"]=val
    df_readindividual.to_csv(outputpath)
